# %%
import importlib
import data_operations as dataops

importlib.reload(dataops)
# Out:
# <module 'data_operations' from '/home/coder/project/code/data_operations.py'>

# %%
df = dataops.update_bills_data(mode='fetch', start_date='2025-01-03')
df
# Out:
# [법안 데이터 수집 및 전송 시작]
# [2025-01-03 ~ 2025-01-04 의안주요내용 데이터 수집 시작]
# [모든 파일 다운로드 완료! 전체 소요 시간: 0.37초]
# [19 개의 법안 수집됨.]
# [결측치 처리 완료. 18 개의 법안 수집됨.]
#
# 발의일자별 수집한 데이터 수 :
# proposeDate
# 2025-01-03    18
# Name: count, dtype: int64
#
# [법안 정보 데이터 수집 중]
# 100%|██████████| 18/18 [00:26<00:00,  1.46s/it]
# 다운로드 완료! 총 소요 시간: 26.25초
# [18개의 법안 정보 데이터가 수집되었습니다.]
# 컬럼 필터링 및 컬럼명 변경 완료
#
# [데이터프레임 병합 진행 중...]
# 데이터프레임 병합 완료
# 18 개의 법안 데이터 병합됨.
#
# [AI 요약 데이터 컬럼 추가 완료]
# proposeDate
# 2025-01-03    18
# Name: count, dtype: int64
#
# [의원 발의자 데이터 수집 및 병합 중...]
# Requesting page 1...
# Requesting page 2...
# Requesting page 3...
# [모든 파일 다운로드 완료! 전체 소요 시간: 0.75초]
# [300 개의 의원 데이터 수집됨]
# 100%|██████████| 18/18 [00:01<00:00, 13.04it/s]
# [의원 발의자 데이터 수집 및 병합 완료]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
# ...

# %%
start_date = '2024-12-31'
end_date = '2025-01-04'


df_billsContent = dataops.fetch_bills_content(start_date, end_date)
df_billsContent
# Out:
# [2024-12-31 ~ 2025-01-04 의안주요내용 데이터 수집 시작]
# [모든 파일 다운로드 완료! 전체 소요 시간: 1.57초]
# [117 개의 법안 수집됨.]
# [결측치 처리 완료. 112 개의 법안 수집됨.]
#
# 발의일자별 수집한 데이터 수 :
# proposeDate
# 2024-12-31    69
# 2025-01-02    25
# 2025-01-03    18
# Name: count, dtype: int64
#     proposeDate billNumber                                            summary  \
# 0    2025-01-03    2207233  제안이유 및 주요내용\r\n\r\n  현행법에서는 대학교육기관의 장 및 대학교육기관...
# 1    2025-01-03    2207232  제안이유 및 주요내용\r\n\r\n  보험설계사, 학습지 방문교사, 택배원 등 노무...
# 2    2025-01-03    2207230  제안이유 및 주요내용\r\n\r\n  보험설계사, 학습지 방문교사, 택배원 등 특수...
# 3    2025-01-03    2207229  제안이유 및 주요내용\r\n\r\n  최근 발생한 제주항공 여객기 참사처럼 항공사고...
# 4    2025-01-03    2207228  제안이유 및 주요내용\r\n\r\n  현행법에 따르면 사법경찰관은 검찰청 소속의 검...
# ..          ...        ...                                                ...
# 107  2024-12-31    2207121  제안이유 및 주요내용\r\n\r\n  균형 잡힌 식사를 통한 영양섭취는 노인 건강증...
# 108  2024-12-31    2207120  제안이유 및 주요내용\r\n\r\n  현행법은 산지에서 토석채취를 완료한 후 재해방...
# ...

# %%
df_billsInfo = dataops.fetch_bills_info(start_date, end_date)
df_billsInfo
# Out:
# [2024-12-31부터 2025-01-04까지의 법안 데이터 수집 중]
# 다운로드 완료! 총 소요 시간: 0.87초
# 수집한 데이터가 없습니다.
